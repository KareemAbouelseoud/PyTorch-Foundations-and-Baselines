# %% [markdown]
# # Setting Up

# %%
import torch
import numpy as np
import pandas as pd
print("CUDA available:", torch.cuda.is_available())
# Out:
# CUDA available: True

# %%
# !nvidia-smi
# Out:
# Thu Jul 23 18:54:00 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 610.74                 KMD Version: 610.74        CUDA UMD Version: 13.3     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 4080 ...  WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   40C    P8              1W /  160W |     198MiB /  12282MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI              PID   Type   Process name                        GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |    0   N/A  N/A           24164      C   ...pythoncore-3.14-64\python.exe      N/A      |
# +-----------------------------------------------------------------------------------------+

# %% [markdown]
# # Manipulating Tensors

# %% [markdown]
# ## 1. Basic Operations

# %% [markdown]
# ### Tensor with Scaler

# %% [markdown]
# #### Addition

# %%
T = torch.tensor([1,2,3])
T + 10
# Out:
# tensor([11, 12, 13])

# %%
torch.add(T, 10) #not in-place
# Out:
# tensor([11, 12, 13])

# %% [markdown]
# #### Multiplication

# %%
T*10
# Out:
# tensor([10, 20, 30])

# %%
torch.multiply(T, 10) #not in-place
# Out:
# tensor([10, 20, 30])

# %% [markdown]
# #### Division

# %%
T/10
# Out:
# tensor([0.1000, 0.2000, 0.3000])

# %%
torch.divide(T, 10) #not in-place
# Out:
# tensor([0.1000, 0.2000, 0.3000])

# %% [markdown]
# #### Subtraction

# %%
T-10
# Out:
# tensor([-9, -8, -7])

# %%
torch.subtract(T, 10) #not in-place
# Out:
# tensor([-9, -8, -7])

# %% [markdown]
# ### Tensor with Tensor

# %% [markdown]
# #### Addition

# %% [markdown]
# ##### To add tensors together, they have to be either:

# %% [markdown]
# - ##### Same shape (all dimensions are the same)

# %%
a = torch.tensor([[1,2,3],[4,5,6]])
b = torch.tensor([[4,5,6],[7,8,9]])
a + b
# Out:
# tensor([[ 5,  7,  9],
#         [11, 13, 15]])

# %% [markdown]
# - ##### When they are not equal in a certain dimension, one of the dimensions is equal to one (broadcasting)

# %%
a = torch.tensor([[[1,2,3],[10,11,12]]])
print(a.shape)

b= torch.tensor([[[4,5,6]],[[7,8,9]]])
print(b.shape)

a+b
# Out:
# torch.Size([1, 2, 3])
# torch.Size([2, 1, 3])
# tensor([[[ 5,  7,  9],
#          [14, 16, 18]],
#
#         [[ 8, 10, 12],
#          [17, 19, 21]]])

# %% [markdown]
# - ##### One tesnor has fewer dimensions (this is what makes the tensor+scaler work)

# %%
a = torch.tensor([[1,2,3],[10,11,12]])
print(a.shape)
b = torch.tensor([4,5,6])
print(b.shape)

a+b
# Out:
# torch.Size([2, 3])
# torch.Size([3])
# tensor([[ 5,  7,  9],
#         [14, 16, 18]])

# %% [markdown]
# #### Multiplication

# %% [markdown]
# ## 2. Shape-Shifting

# %% [markdown]
# ## 3. Combining & Splitting

# %% [markdown]
# ## 4. Slicing & Indexing

# %% [markdown]
# ## 5. Aggregation
